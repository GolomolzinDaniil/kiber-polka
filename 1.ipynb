# %%
import pandas as pd

# %%
df = pd.read_parquet(r'data\train_main_features.parquet')

# %%
df.info()

# %%
df.describe()

# %%
df.head().T

# %%
category, numeric = [], []

for col in df.columns:
    if col.startswith('cat'): category.append(col)
    else: numeric.append(col)
